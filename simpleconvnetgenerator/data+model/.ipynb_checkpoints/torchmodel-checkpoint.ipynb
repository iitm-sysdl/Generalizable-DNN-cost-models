# %%
import numpy as np
from matplotlib import pyplot as plt 
from numpy import genfromtxt
from sklearn.utils import shuffle
import csv
import torch
import torchvision
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
with open('21/1layer.csv', 'r') as f:
  reader = csv.reader(f)
  d = list(reader)
d = d[1:]
d = np.asarray(d, dtype=float)
onelayerdata = np.zeros((d.shape[0], d.shape[1]+2), dtype=float)
onelayerdata[:,:6]=d[:,:6]
onelayerdata[:,8:10]=d[:,6:9]
onelayerdata=onelayerdata[onelayerdata[:,0]==224]
print(onelayerdata.shape)
d=genfromtxt('21/2layer.csv', delimiter=',')
d=d[:,:-1]
twolayerdata=d
print(twolayerdata.shape)
d=genfromtxt('21/3layer.csv', delimiter=',')
d=d[:,:-1]
threelayerdata=d
print(threelayerdata.shape)

totaldata=np.concatenate((onelayerdata, twolayerdata, threelayerdata))
print(totaldata.shape)
f = totaldata[:,:8]
y = totaldata[:,8]
print(f.shape)

f, y = shuffle(f,y)
trainf = f[:int(0.85*len(f))]
trainy = y[:int(0.85*len(f))]
testf = f[int(0.85*len(f)):]
testy = y[int(0.85*len(f)):]
print(trainf.shape, testf.shape, trainy.shape, testy.shape)
# Out:
# (85, 10)
# (448, 10)
# (5824, 10)
# (6357, 10)
# (6357, 8)
# (5403, 8) (954, 8) (5403,) (954,)

# %%
class numpy2Dataset(Dataset):
  def __init__(self, features, values):
    self.features = features
    self.values = values
  def __len__(self): 
      return len(self.features)
  def __getitem__(self, i): 
      return self.features[i], self.values[i]

# %%
traintensor = numpy2Dataset(trainf, trainy)
trainloader = torch.utils.data.DataLoader(traintensor, batch_size=200)
testtensor = numpy2Dataset(testf, testy)
testloader = torch.utils.data.DataLoader(testtensor, batch_size=200)

# %%
model = nn.Sequential(nn.Linear(8,100), nn.Linear(100,1))
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

# %%
def train():
    model.train()
    for data, target in trainloader:
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += criterion(output, target, reduction='sum').item()
    return train_loss

def test():
    model.eval()
    for data, target in testloader:
        output = model(data)
        test_loss += criterion(output, target, reduction='sum').item()
    return test_loss

# %%
num_epoch = 200
for epoch in range(num_epoch):
    train_loss=train()
    test_loss=test()
    if epoch % 50 ==0:
        print("Epoch: {} Train Loss: {}".format(epoch, train_loss))
        print("Epoch: {} Test Loss: {}".format(epoch, test_loss))
print("Test Loss: {}".format(test()))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-c48a3a30c992> in <module>
#       1 num_epoch = 200
#       2 for epoch in range(num_epoch):
# ----> 3     train_loss=train()
#       4     test_loss=test()
#       5     if epoch % 50 ==0:
#
# <ipython-input-31-1b778d951439> in train()
#       3     for data, target in trainloader:
#       4         optimizer.zero_grad()
# ----> 5         output = model(data)
#       6         loss = criterion(output, target)
#       7         loss.backward()
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# RuntimeError: Expected object of scalar type Float but got scalar type Double for argument #2 'mat1' in call to _th_addmm

# %%
from sklearn.neural_network import MLPRegressor
dnn21 = MLPRegressor(hidden_layer_sizes=(100))
dnn21.fit(trainx, trainy)
print(dnn21.score(testx, testy))
pred = dnn21.predict(testx)
print(np.sqrt(np.mean((testy-pred)**2)))
# Out:
# 0.9993502896103409

# %%
pred = dnn21.predict(testx)
print(np.sqrt(np.mean((testy-pred)**2)))
# Out:
# 7685.11076841617

# %%
plt.xlabel("Actual Value Latency")
plt.ylabel("Predicted Value Latency")
plt.scatter(testy, pred)
plt.show()

# %%
with open('237/1layer.csv', 'r') as f:
  reader = csv.reader(f)
  d = list(reader)
d = d[1:]
d = np.asarray(d, dtype=float)
onelayerdata = np.zeros((d.shape[0], d.shape[1]+2), dtype=float)
onelayerdata[:,:6]=d[:,:6]
onelayerdata[:,8:10]=d[:,6:9]
onelayerdata=onelayerdata[onelayerdata[:,0]==224]
print(onelayerdata.shape)
d=genfromtxt('237/2layer.csv', delimiter=',')
d=d[:,:-1]
twolayerdata=d
print(twolayerdata.shape)
d=genfromtxt('237/3layer.csv', delimiter=',')
d=d[:,:-1]
threelayerdata=d
print(threelayerdata.shape)

totaldata=np.concatenate((onelayerdata, twolayerdata, threelayerdata))
print(totaldata.shape)
f = totaldata[:,:8]
y = totaldata[:,8]
print(f.shape)
from sklearn.utils import shuffle
f, y = shuffle(f,y)
trainx = f[:int(0.85*len(f))]
trainy = y[:int(0.85*len(f))]
testx = f[int(0.85*len(f)):]
testy = y[int(0.85*len(f)):]
print(trainx.shape, testx.shape)
# Out:
# (85, 10)
# (448, 10)
# (5824, 10)
# (6357, 10)
# (6357, 8)
# (5403, 8) (954, 8)

# %%
dnn237 = MLPRegressor(hidden_layer_sizes=(400,400, 100))
dnn237.fit(trainx, trainy)
print(dnn237.score(testx, testy))
pred = dnn237.predict(testx)
print(np.sqrt(np.mean((testy-pred)**2)))
plt.xlabel("Actual Value Latency")
plt.ylabel("Predicted Value Latency")
plt.scatter(testy, pred)
plt.show()
# Out:
# 0.9778454659009018
# 20840.904538053972
