# %%
import numpy as np
import seaborn as sns
sns.set() 
import pandas as pd
import os
from matplotlib import pyplot as plt
import glob

# %%
files = glob.glob('*.txt')
print(files)    
# files = ['Pixel_4_XL_17-05-2020-06-31-47.txt', 'storage_emulated_10_Documents_Pixel_C_17-05-2020-08-14-19.txt']
for file in files:
    data = pd.read_csv(file, sep=",", header=None)
    data['mean'] = data.mean(axis=1)
    data = data[data.index < 120]
    data.boxplot(column=['mean'], return_type='axes')
    plt.title(file)
    plt.show()
# Out:
# ['storage_emulated_0_Documents_SM-G930F_17-05-2020-02-25-13.txt', 'storage_emulated_0_Documents_ONEPLUS_A5010_16-05-2020-07-48-01.txt', 'storage_emulated_0_Documents_Redmi_K20_Pro_17-05-2020-02-01-57.txt', 'SM-G610F_17-05-2020-10-26-17.txt', 'storage_emulated_0_Documents_ONEPLUS_A6000_16-05-2020-08-52-53.txt', 'SM-G965U1_17-05-2020-11-40-12.txt', 'storage_emulated_0_Documents_KFMUWI_16-05-2020-04-17-37.txt', 'storage_emulated_0_Documents_SM-M307F_17-05-2020-07-13-27.txt', 'SM-N975F_17-05-2020-09-46-49.txt', 'storage_emulated_0_Documents_GM1901_16-05-2020-06-04-46.txt', 'storage_emulated_0_Documents_Redmi_Note_3_17-05-2020-07-33-27.txt', 'SM-N970F_17-05-2020-06-58-55.txt', 'SM-G975U1_17-05-2020-09-43-50.txt', 'SM-T830_17-05-2020-11-18-40.txt', 'storage_emulated_0_Documents_Redmi_Note_5_Pro_16-05-2020-04-40-56.txt', 'Redmi_Note_6_Pro_17-05-2020-08-38-55.txt', 'Pixel_3_XL_17-05-2020-06-48-04.txt', 'storage_emulated_0_Documents_SM-M307F_16-05-2020-11-01-49.txt', 'storage_emulated_0_Docum
# ...

# %%
files = ['Pixel_4_XL_17-05-2020-06-31-47.txt', 'storage_emulated_10_Documents_Pixel_C_17-05-2020-08-14-19.txt']
a = files[0]
if a.startswith('storage'):
# Out:
# None
